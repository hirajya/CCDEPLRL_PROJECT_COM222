# %%
# %pip install tensorflow numpy matplotlib pillow scikit-learn seaborn

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, regularizers
import os
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import seaborn as sns
# Out:
# Requirement already satisfied: tensorflow in c:\users\ella\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: numpy in c:\users\ella\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\ella\anaconda3\lib\site-packages (3.10.1)
# Requirement already satisfied: pillow in c:\users\ella\anaconda3\lib\site-packages (10.4.0)
# Requirement already satisfied: scikit-learn in c:\users\ella\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: seaborn in c:\users\ella\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\ella\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ella\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ella\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ella\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ella\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ella\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ella\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ella\anaconda3\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ella\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ella\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ella\anaconda3\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ella\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\ella\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\ella\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.9)
# Requirement already satisfied: optree in c:\users\ella\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.15.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ella\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ella\anaconda3\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ella\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ella\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ella\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ella\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ella\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ella\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ella\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ella\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ella\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ella\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ella\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Data Loading and Preprocessing

# %%
def load_binary_data(data_dir='dataset/Wound_dataset copy', img_size=(224, 224)):
    images = []
    labels = []
    
    # Process bruise images (positive class)
    bruise_path = os.path.join(data_dir, 'Bruises')
    if os.path.exists(bruise_path):
        for img_name in os.listdir(bruise_path):
            if img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(bruise_path, img_name)
                try:
                    img = Image.open(img_path)
                    img = img.convert('RGB')
                    img = img.resize(img_size)
                    img_array = np.array(img) / 255.0
                    
                    images.append(img_array)
                    labels.append(1)  # 1 for bruise
                except Exception as e:
                    print(f"Error loading {img_path}: {e}")
    
    # Process normal skin images (negative class)
    normal_path = os.path.join(data_dir, 'Normal')
    if os.path.exists(normal_path):
        for img_name in os.listdir(normal_path):
            if img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
                img_path = os.path.join(normal_path, img_name)
                try:
                    img = Image.open(img_path)
                    img = img.convert('RGB')
                    img = img.resize(img_size)
                    img_array = np.array(img) / 255.0
                    
                    images.append(img_array)
                    labels.append(0)  # 0 for normal
                except Exception as e:
                    print(f"Error loading {img_path}: {e}")
    
    return np.array(images), np.array(labels)

# %% [markdown]
# Load the dataset

# %%
X, y = load_binary_data()
print("Dataset shape:", X.shape)
print("Number of bruise images:", np.sum(y == 1))
print("Number of normal images:", np.sum(y == 0))
# Out:
# Dataset shape: (442, 224, 224, 3)
# Number of bruise images: 242
# Number of normal images: 200

# %% [markdown]
# Data Splitting

# %%
X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=0.1, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=0.20, random_state=42)
print("\nData split sizes:")
print(f"Training set: {len(X_train)} images")
print(f"Validation set: {len(X_val)} images")
print(f"Test set: {len(X_test)} images")
# Out:
# Data split sizes:
# Training set: 317 images
# Validation set: 80 images
# Test set: 45 images

# %% [markdown]
# Model Definition with Dropout (0.5) + L2 Regularization

# %%
def create_dropout_l2_model(input_shape, dropout_rate=0.5, l2_lambda=0.001):
    model = models.Sequential([
        layers.Input(shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu',
                      kernel_regularizer=regularizers.l2(l2_lambda)),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout_rate),
        layers.Flatten(),
        layers.Dense(64, activation='relu',
                     kernel_regularizer=regularizers.l2(l2_lambda)),
        layers.Dropout(dropout_rate),
        layers.Dense(1, activation='sigmoid')
    ])
    return model

input_shape = X_train[0].shape
model = create_dropout_l2_model(input_shape, dropout_rate=0.5, l2_lambda=0.001)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 15
#      12     return model
#      14 input_shape = X_train[0].shape
# ---> 15 model = create_l2_model(input_shape, l2_lambda=0.001)
#
# Cell In[5], line 5, in create_l2_model(input_shape, l2_lambda)
#       1 def create_l2_model(input_shape, l2_lambda=0.001):
#       2     model = models.Sequential([
#       3         layers.Input(shape=input_shape),
#       4         layers.Conv2D(32, (3, 3), activation='relu',
# ----> 5                       kernel_regularizer=regularizers.l2(l2_lambda)),
#       6         layers.MaxPooling2D((2, 2)),
#       7         layers.Flatten(),
#       8         layers.Dense(64, activation='relu',
#       9                      kernel_regularizer=regularizers.l2(l2_lambda)),
#      10         layers.Dense(1, activation='sigmoid')
#      11     ])
#      12     return model
#
# NameError: name 'regularizers' is not defined

# %% [markdown]
# Model Compilation

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()]
)

# %% [markdown]
# Model Training

# %%
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1
)
# Out:
# Epoch 1/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 19s 982ms/step - accuracy: 0.4981 - loss: 7.9295 - precision: 0.4968 - recall: 0.5200 - val_accuracy: 0.5500 - val_loss: 2.3643 - val_precision: 0.5500 - val_recall: 1.0000
# Epoch 2/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 891ms/step - accuracy: 0.6858 - loss: 1.7174 - precision: 0.6968 - recall: 0.7774 - val_accuracy: 0.7625 - val_loss: 0.5303 - val_precision: 0.9310 - val_recall: 0.6136
# Epoch 3/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 892ms/step - accuracy: 0.6918 - loss: 0.5421 - precision: 0.6938 - recall: 0.8330 - val_accuracy: 0.8500 - val_loss: 0.4684 - val_precision: 0.9000 - val_recall: 0.8182
# Epoch 4/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 902ms/step - accuracy: 0.8136 - loss: 0.4446 - precision: 0.8129 - recall: 0.8720 - val_accuracy: 0.8375 - val_loss: 0.4791 - val_precision: 0.9429 - val_recall: 0.7500
# Epoch 5/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 945ms/step - accuracy: 0.8761 - loss: 0.4673 - precision: 0.9092 - recall: 0.8407 - val_accuracy: 0.8500 - val_loss: 0.4194 - val_precision: 0.9000 - val_recall: 0.8182
# Epoch 6/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 926ms/step - accuracy: 0.8916 - loss: 0.4062 - precision: 0.9576 - recall: 0.8441 - val_accuracy: 0.7875 - val_loss: 0.4512 - val_precision: 0.9355 - val_recall: 0.6591
# Epoch 7/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.8280 - loss: 0.4268 - precision: 0.9025 - recall: 0.7317 - val_accuracy: 0.7500 - val_loss: 0.4842 - val_precision: 0.7500 - val_recall: 0.8182
# Epoch 8/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 942ms/step - accuracy: 0.8147 - loss: 0.4120 - precision: 0.8834 - recall: 0.7774 - val_accuracy: 0.8250 - val_loss: 0.3971 - val_precision: 1.0000 - val_recall: 0.6818
# Epoch 9/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 920ms/step - accuracy: 0.8457 - loss: 0.3808 - precision: 0.9396 - recall: 0.7553 - val_accuracy: 0.8125 - val_loss: 0.3939 - val_precision: 0.9394 - val_recall: 0.7045
# Epoch 10/10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 941ms/step - accuracy: 0.8718 - loss: 0.3233 - precision: 0.9240 - recall: 0.8306 - val_accuracy: 0.8500 - val_loss: 0.3380 - val_precision: 0.9444 - val_recall: 0.7727

# %% [markdown]
# Plot Training History (Accuracy/Loss/Precision/Recall)

# %%
def plot_training_history(history):
    metrics = ['loss', 'accuracy', 'precision', 'recall']
    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    for idx, metric in enumerate(metrics):
        row = idx // 2
        col = idx % 2
        axes[row, col].plot(history.history[metric], label=f'Training {metric}')
        axes[row, col].plot(history.history[f'val_{metric}'], label=f'Validation {metric}')
        axes[row, col].set_title(f'Model {metric.capitalize()}')
        axes[row, col].set_xlabel('Epoch')
        axes[row, col].set_ylabel(metric.capitalize())
        axes[row, col].legend()
        axes[row, col].grid(True)
    plt.tight_layout()
    plt.show()

plot_training_history(history)

# %% [markdown]
# Model Evaluation on Test Set

# %%
# Predict probabilities and classes
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Normal', 'Bruise'],
            yticklabels=['Normal', 'Bruise'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Classification Report (Precision, Recall, F1-score)
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=['Normal', 'Bruise']))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.86      0.90      0.88        21
#       Bruise       0.91      0.88      0.89        24
#
#     accuracy                           0.89        45
#    macro avg       0.89      0.89      0.89        45
# weighted avg       0.89      0.89      0.89        45

# %%
# ROC Curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %% [markdown]
# Save the Model

# %%
model.save('models/ruise_detection_dropout05_l2.h5')
print("Model saved as bruise_detection_l2.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as bruise_detection_dropout_05.h5
